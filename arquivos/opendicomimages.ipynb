# %%
# !pip install matplotlib
# !pip install pydicom
# Out:
# Requirement already satisfied: matplotlib in /home/ashiley/miniconda3/lib/python3.10/site-packages (3.8.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: numpy<2,>=1.21 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: cycler>=0.10 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: six>=1.5 in /home/ashiley/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pydicom in /home/ashiley/miniconda3/lib/python3.10/site-packages (2.4.3)

# %%
import matplotlib.pyplot as plt
from pydicom.data import get_testdata_files
from pydicom.filereader import dcmread

# %%
import pydicom
import os

pasta_raiz = '/A/motomed/radiomics/data/download/manifest-1600709154662/LIDC-IDRI/LIDC-IDRI-0001/01-01-2000-NA-NA-35511/'

nome_do_arquivo = '1-1.dcm'

def encontrar_arquivo_dicom(pasta):
    for pasta_atual, subpastas, arquivos in os.walk(pasta):
        for arquivo in arquivos:
            if arquivo == nome_do_arquivo:
                caminho_completo = os.path.join(pasta_atual, arquivo)
                ds = pydicom.dcmread(caminho_completo)
                return ds
    return None

imagem_dicom = encontrar_arquivo_dicom(pasta_raiz)
if imagem_dicom:
    print("Arquivo DICOM encontrado e carregado.")
else:
    print("Arquivo DICOM não encontrado.")
    
imagem_dicom
# Out:
# Arquivo DICOM encontrado e carregado.
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 208
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.307896144859643716158189196068
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0013) Implementation Version Name         SH: '0.5'
# (0002, 0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', '']
# (0008, 0016) SOP Class UID                       UI: Digital X-Ray Image Storage - For Presentation
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.307896144859643716158189196068
# (0008, 0020) Study Date                          DA: '20000101'
# (0008, 0021) Series Date                         DA: '20000101'
# (0008, 0022) Acquisition Date                    DA: '20000101'
# (0008, 0023) Content Date                        DA: '20000101'
# (0008, 0024) Overlay Date                        DA: '20000101'
# (0008, 0025) Curve Date                          DA: '20000101'
# (0008, 002a) Acquisition DateTime                DT: '20000101'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0032) Acquisition Time                    TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'DX'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Revolution XQi ADS_28.2'
# (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.715812073192851683888390563022
# (0010, 0010) Patient's Name                      PN: ''
# (0010, 0020) Patient ID                          LO: 'LIDC-IDRI-0001'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 21d0) Last Menstrual Date                 DA: '20000101'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'DCM:113100/113105/113107/113108/113109/113111'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'LIDC-IDRI'
# (0013, 1013) Private tag data                    LO: '62796001'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0060) KVP                                 DS: '125.0'
# (0018, 1020) Software Versions                   LO: 'Ads Application Package VERSION ADS_28.2'
# (0018, 1110) Distance Source to Detector         DS: '1800.0'
# (0018, 1111) Distance Source to Patient          DS: '1750.0'
# (0018, 1150) Exposure Time                       IS: '7'
# (0018, 1151) X-Ray Tube Current                  IS: '320'
# (0018, 1152) Exposure                            IS: '2'
# (0018, 1160) Filter Type                         SH: 'NONE'
# (0018, 1190) Focal Spot(s)                       DS: '1.25'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.175012972118199124641098335511
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.141365756818074696859567662357
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '3000923'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ['L', 'F']
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.313477544115338489981733920769
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 2022
# (0028, 0011) Columns                             US: 2022
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 14
# (0028, 0102) High Bit                            US: 13
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '-600.0'
# (0028, 1051) Window Width                        DS: '1600.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0038, 0020) Admitting Date                      DA: '20000101'
# (0040, 0002) Scheduled Procedure Step Start Date DA: '20000101'
# (0040, 0004) Scheduled Procedure Step End Date   DA: '20000101'
# (0040, 0244) Performed Procedure Step Start Date DA: '20000101'
# (0040, 2016) Placer Order Number / Imaging Servi LO: ''
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (0040, a075) Verifying Observer Name             PN: 'Removed by CTP'
# (0040, a123) Person Name                         PN: 'Removed by CTP'
# (0040, a124) UID                                 UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.297040423659775296818715026012
# (0070, 0084) Content Creator's Name              PN: ''
# (0088, 0140) Storage Media File-set UID          UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.184019247969808410716143213081
# (7fe0, 0010) Pixel Data                          OW: Array of 8176968 elements

# %%
pixel_array = imagem_dicom.pixel_array

plt.figure(figsize=(8, 8))
plt.imshow(pixel_array, cmap=plt.cm.bone)
plt.title("Imagem de Raio-X")
plt.show()

# %%
patient_name = imagem_dicom.PatientName
print("Patient's Name:", patient_name)

pixel_array = imagem_dicom.pixel_array
print("Pixel array", pixel_array)
# Out:
# Patient's Name:
# Pixel array [[2203 2199 2263 ... 1446 1436 1404]
#  [2300 2300 2367 ... 1597 1542 1477]
#  [2322 2410 2383 ... 1641 1608 1537]
#  ...
#  [ 414  434  457 ...  313  322  301]
#  [ 430  429  449 ...  306  322  298]
#  [ 472  449  427 ...  327  311  307]]

# %%
#Sintaxe da documentacao 

plt.imshow(imagem_dicom.pixel_array, cmap=plt.cm.bone)
plt.title("Imagem de Raio-X")
plt.show()

# %%
import numpy as np

pasta_tomografia = '/A/motomed/radiomics/data/download/manifest-1600709154662/LIDC-IDRI/LIDC-IDRI-0002/01-01-2000-NA-NA-98329/3000522.000000-NA-04919/'

arquivos_dicom = [os.path.join(pasta_tomografia, arquivo) for arquivo in os.listdir(pasta_tomografia) if arquivo.endswith('.dcm')]

arquivos_dicom.sort()

volume_3d = np.stack([pydicom.dcmread(arquivo).pixel_array for arquivo in arquivos_dicom])

plt.figure(figsize=(10, 10))
plt.imshow(volume_3d[0, :, :], cmap=plt.cm.bone)
plt.title("Tomografia Computadorizada 3D")
plt.show()

# %%
from ipywidgets import interact

def visualizar_tomografia(corte):
    ds = pydicom.dcmread(arquivos_dicom[corte])
    pixel_array = ds.pixel_array

    plt.figure(figsize=(8, 8))
    plt.imshow(pixel_array, cmap=plt.cm.bone)
    plt.title(f"Tomografia - Corte {corte}")
    plt.show()

interact(visualizar_tomografia, corte=(0, len(arquivos_dicom)-1))
# Out:
# interactive(children=(IntSlider(value=130, description='corte', max=260), Output()), _dom_classes=('widget-int…
# <function __main__.visualizar_tomografia(corte)>

# %%
instance_number = imagem_dicom.InstanceNumber
print(instance_number)
# Out:
# 1

# %% [markdown]
# Função para renomear cortes de tomografia com nome saleatórios,
# assim, podemos aprender a ordena-los através do instance number

# %%
import shutil
import random

def copy_files_randomly(source_folder, destination_folder):
    files = os.listdir(source_folder)

    random.shuffle(files)

    for filename in files:
        source_file = os.path.join(source_folder, filename)
        destination_file = os.path.join(destination_folder, filename)
        shutil.copy(source_file, destination_file)
        print(f"Arquivo copiado: {filename}")

if __name__ == "__main__":
    source_folder = '/A/motomed/radiomics/data/download/manifest-1600709154662/LIDC-IDRI/LIDC-IDRI-0002/01-01-2000-NA-NA-98329/3000522.000000-NA-04919/'
    destination_folder = '/A/motomed/radiomics/data/download/manifest-1600709154662/LIDC-IDRI/LIDC-IDRI-0002/teste/'

    copy_files_randomly(source_folder, destination_folder)
# Out:
# Arquivo copiado: 1-211.dcm
# Arquivo copiado: 1-221.dcm
# Arquivo copiado: 1-088.dcm
# Arquivo copiado: 1-081.dcm
# Arquivo copiado: 1-065.dcm
# Arquivo copiado: 1-128.dcm
# Arquivo copiado: 1-189.dcm
# Arquivo copiado: 1-145.dcm
# Arquivo copiado: 1-171.dcm
# Arquivo copiado: 1-208.dcm
# Arquivo copiado: 1-158.dcm
# Arquivo copiado: 1-004.dcm
# Arquivo copiado: 1-032.dcm
# Arquivo copiado: 1-198.dcm
# Arquivo copiado: 1-010.dcm
# Arquivo copiado: 1-060.dcm
# Arquivo copiado: 1-238.dcm
# Arquivo copiado: 1-050.dcm
# Arquivo copiado: 1-258.dcm
# Arquivo copiado: 1-213.dcm
# Arquivo copiado: 1-096.dcm
# Arquivo copiado: 1-191.dcm
# Arquivo copiado: 1-246.dcm
# Arquivo copiado: 1-097.dcm
# Arquivo copiado: 1-083.dcm
# Arquivo copiado: 1-234.dcm
# Arquivo copiado: 1-131.dcm
# Arquivo copiado: 1-136.dcm
# Arquivo copiado: 1-029.dcm
# Arquivo copiado: 1-041.dcm
# Arquivo copiado: 1-121.dcm
# Arquivo copiado: 1-037.dcm
# Arquivo copiado: 1-025.dcm
# Arquivo copiado: 1-111.dcm
# Arquivo copiado: 1-112.dcm
# Arquivo copiado: 1-181.dcm
# Arquivo copiado: 1-199.dcm
# Arquivo copiado: 1-123.dcm
# Arquivo copiado: 1-164.dcm
# Arquivo copiado: 1-129.dcm
# Arquivo copiado: 1-170.dcm
# Arquivo copiado: 1-027.dcm
# Arquivo copiado: 1-231.dcm
# Arquivo copiado: 1-163.dcm
# Arquivo copiado: 1-175.dcm
# Arquivo copiado: 1-190.dcm
# Arquivo copiado: 1-005.dcm
# Arquivo copiado: 1-024.dcm
# Arquivo copiado: 1-011.dcm
# Arquivo copiado: 1-169.dcm
# Arquivo copiado: 1-053.dcm
# Arquivo copiado: 1-259.dcm
# Arquivo copiado: 1-201.dcm
# Arquivo copiado: 1-229.dcm
# Arquivo copiado: 1-135.dcm
# Arquivo copiado: 1-019.dcm
# Arquivo copiado: 1-132.dcm
# Arquivo copiado: 1-150.dcm
# Arquivo copiado: 1-062.dcm
# Arquivo copiado: 1-058.dcm
# Arquivo copiado: 1-156.dcm
# Arquivo copiado: 1-069.dcm
# Arquivo copiado: 1-104.dcm
# Arquivo copiado: 1-106.dcm
# Arquivo copiado: 1-202.dcm
# Arquivo copiado: 1-110.dcm
# Arquivo copiado: 1-161.dcm
# Arquivo copiado: 1-109.dcm
# Arquivo copiado: 1-115.dcm
# Arquivo copiado: 1-119.dcm
# Arquivo copiado: 1-148.dcm
# Arquivo copiado: 1-219.dcm
# Arquivo copiado: 1-057.dcm
# Arquivo copiado: 1-260.dcm
# Arquivo copiado: 1-179.dcm
# Arquivo copiado: 1-152.dcm
# Arquivo copiado: 1-224.dcm
# Arquivo copiado: 1-139.dcm
# Arquivo copiado: 1-257.dcm
# Arquivo copiado: 1-099.dcm
# Arquivo copiado: 1-101.dcm
# Arquivo copiado: 1-090.dcm
# Arquivo copiado: 1-049.dcm
# Arquivo copiado: 1-244.dcm
# Arquivo copiado: 1-248.dcm
# Arquivo copiado: 1-194.dcm
# Arquivo copiado: 1-168.dcm
# Arquivo copiado: 1-206.dcm
# Arquivo copiado: 1-082.dcm
# Arquivo copiado: 1-196.dcm
# Arquivo copiado: 1-045.dcm
# Arquivo copiado: 1-120.dcm
# Arquivo copiado: 1-153.dcm
# Arquivo copiado: 1-094.dcm
# Arquivo copiado: 1-033.dcm
# Arquivo copiado: 1-143.dcm
# Arquivo copiado: 1-022.dcm
# Arquivo copiado: 1-023.dcm
# Arquivo copiado: 1-064.dcm
# Arquivo copiado: 1-074.dcm
# Arquivo copiado: 1-245.dcm
# Arquivo copiado: 1-047.dcm
# Arquivo copiado: 1-075.dcm
# Arquivo copiado: 1-044.dcm
# Arquivo copiado: 1-122.dcm
# Arquivo copiado: 1-173.dcm
# Arquivo copiado: 1-185.dcm
# Arquivo copiado: 1-092.dcm
# Arquivo copiado: 1-031.dcm
# Arquivo copiado: 1-149.dcm
# Arquivo copiado: 1-007.dcm
# Arquivo copiado: 1-174.dcm
# Arquivo copiado: 1-034.dcm
# Arquivo copiado: 1-249.dcm
# Arquivo copiado: 1-255.dcm
# Arquivo copiado: 1-026.dcm
# Arquivo copiado: 1-210.dcm
# Arquivo copiado: 1-200.dcm
# Arquivo copiado: 1-130.dcm
# Arquivo copiado: 1-177.dcm
# Arquivo copiado: 1-035.dcm
# Arquivo copiado: 1-230.dcm
# Arquivo copiado: 1-078.dcm
# Arquivo copiado: 1-252.dcm
# Arquivo copiado: 1-188.dcm
# Arquivo copiado: 1-183.dcm
# Arquivo copiado: 1-073.dcm
# Arquivo copiado: 1-205.dcm
# Arquivo copiado: 1-127.dcm
# Arquivo copiado: 1-079.dcm
# Arquivo copiado: 1-146.dcm
# Arquivo copiado: 1-020.dcm
# Arquivo copiado: 1-239.dcm
# Arquivo copiado: 1-002.dcm
# Arquivo copiado: 1-228.dcm
# Arquivo copiado: 1-247.dcm
# Arquivo copiado: 1-087.dcm
# Arquivo copiado: 1-103.dcm
# Arquivo copiado: 1-155.dcm
# Arquivo copiado: 1-222.dcm
# Arquivo copiado: 1-176.dcm
# Arquivo copiado: 1-046.dcm
# Arquivo copiado: 1-102.dcm
# Arquivo copiado: 1-043.dcm
# Arquivo copiado: 1-070.dcm
# Arquivo copiado: 1-216.dcm
# Arquivo copiado: 1-251.dcm
# Arquivo copiado: 1-108.dcm
# Arquivo copiado: 1-038.dcm
# Arquivo copiado: 1-051.dcm
# Arquivo copiado: 1-008.dcm
# Arquivo copiado: 1-225.dcm
# Arquivo copiado: 1-013.dcm
# Arquivo copiado: 1-028.dcm
# Arquivo copiado: 1-226.dcm
# Arquivo copiado: 1-039.dcm
# Arquivo copiado: 071.xml
# Arquivo copiado: 1-063.dcm
# Arquivo copiado: 1-140.dcm
# Arquivo copiado: 1-133.dcm
# Arquivo copiado: 1-067.dcm
# Arquivo copiado: 1-261.dcm
# Arquivo copiado: 1-105.dcm
# Arquivo copiado: 1-114.dcm
# Arquivo copiado: 1-054.dcm
# Arquivo copiado: 1-137.dcm
# Arquivo copiado: 1-182.dcm
# Arquivo copiado: 1-016.dcm
# Arquivo copiado: 1-068.dcm
# Arquivo copiado: 1-256.dcm
# Arquivo copiado: 1-178.dcm
# Arquivo copiado: 1-052.dcm
# Arquivo copiado: 1-180.dcm
# Arquivo copiado: 1-042.dcm
# Arquivo copiado: 1-118.dcm
# Arquivo copiado: 1-085.dcm
# Arquivo copiado: 1-040.dcm
# Arquivo copiado: 1-084.dcm
# Arquivo copiado: 1-113.dcm
# Arquivo copiado: 1-166.dcm
# Arquivo copiado: 1-203.dcm
# Arquivo copiado: 1-227.dcm
# Arquivo copiado: 1-048.dcm
# Arquivo copiado: 1-080.dcm
# Arquivo copiado: 1-254.dcm
# Arquivo copiado: 1-116.dcm
# Arquivo copiado: 1-009.dcm
# Arquivo copiado: 1-015.dcm
# Arquivo copiado: 1-167.dcm
# Arquivo copiado: 1-072.dcm
# Arquivo copiado: 1-117.dcm
# Arquivo copiado: 1-126.dcm
# Arquivo copiado: 1-172.dcm
# Arquivo copiado: 1-218.dcm
# Arquivo copiado: 1-076.dcm
# Arquivo copiado: 1-001.dcm
# Arquivo copiado: 1-243.dcm
# Arquivo copiado: 1-154.dcm
# Arquivo copiado: 1-212.dcm
# Arquivo copiado: 1-091.dcm
# Arquivo copiado: 1-223.dcm
# Arquivo copiado: 1-100.dcm
# Arquivo copiado: 1-214.dcm
# Arquivo copiado: 1-055.dcm
# Arquivo copiado: 1-242.dcm
# Arquivo copiado: 1-018.dcm
# Arquivo copiado: 1-077.dcm
# Arquivo copiado: 1-215.dcm
# Arquivo copiado: 1-193.dcm
# Arquivo copiado: 1-162.dcm
# Arquivo copiado: 1-236.dcm
# Arquivo copiado: 1-006.dcm
# Arquivo copiado: 1-036.dcm
# Arquivo copiado: 1-147.dcm
# Arquivo copiado: 1-241.dcm
# Arquivo copiado: 1-144.dcm
# Arquivo copiado: 1-095.dcm
# Arquivo copiado: 1-030.dcm
# Arquivo copiado: 1-237.dcm
# Arquivo copiado: 1-159.dcm
# Arquivo copiado: 1-066.dcm
# Arquivo copiado: 1-125.dcm
# Arquivo copiado: 1-220.dcm
# Arquivo copiado: 1-142.dcm
# Arquivo copiado: 1-240.dcm
# Arquivo copiado: 1-056.dcm
# Arquivo copiado: 1-089.dcm
# Arquivo copiado: 1-207.dcm
# Arquivo copiado: 1-138.dcm
# Arquivo copiado: 1-014.dcm
# Arquivo copiado: 1-186.dcm
# Arquivo copiado: 1-003.dcm
# Arquivo copiado: 1-232.dcm
# Arquivo copiado: 1-235.dcm
# Arquivo copiado: 1-124.dcm
# Arquivo copiado: 1-209.dcm
# Arquivo copiado: 1-160.dcm
# Arquivo copiado: 1-098.dcm
# Arquivo copiado: 1-086.dcm
# Arquivo copiado: 1-093.dcm
# Arquivo copiado: 1-195.dcm
# Arquivo copiado: 1-061.dcm
# Arquivo copiado: 1-017.dcm
# Arquivo copiado: 1-059.dcm
# Arquivo copiado: 1-012.dcm
# Arquivo copiado: 1-071.dcm
# Arquivo copiado: 1-151.dcm
# Arquivo copiado: 1-107.dcm
# Arquivo copiado: 1-217.dcm
# Arquivo copiado: 1-021.dcm
# Arquivo copiado: 1-233.dcm
# Arquivo copiado: 1-184.dcm
# Arquivo copiado: 1-157.dcm
# Arquivo copiado: 1-204.dcm
# Arquivo copiado: 1-192.dcm
# Arquivo copiado: 1-187.dcm
# Arquivo copiado: 1-141.dcm
# Arquivo copiado: 1-197.dcm
# Arquivo copiado: 1-253.dcm
# Arquivo copiado: 1-250.dcm
# Arquivo copiado: 1-134.dcm
# Arquivo copiado: 1-165.dcm

# %%
import shutil
import random
import string


def rename_dicom_files_with_random_names(folder_path):

    files = os.listdir(folder_path)

    random.shuffle(files)

    for old_filename in files: #lista com nomes antigos dos arquivos
        
        old_filepath = os.path.join(folder_path, old_filename)

        if old_filename.lower().endswith('.dcm'):
 
            #renomeia aleatoriamente
            new_filename = ''.join(random.choice(string.ascii_letters + string.digits) for _ in range(8)) + '.dcm'

            new_filepath = os.path.join(folder_path, new_filename)
            shutil.move(old_filepath, new_filepath)
            
        else:
            print(f"Arquivo não DICOM: {old_filename}")

if __name__ == "__main__":
    rename_dicom_files_with_random_names(destination_folder)
# Out:
# Arquivo não DICOM: 071.xml

# %%
def print_instance_numbers(folder_path):
    
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        if filename.lower().endswith('.dcm'):
            arquivo = pydicom.dcmread(file_path)
            instance_number = arquivo.InstanceNumber
            print(f"Nome do arquivo: {filename}, InstanceNumber: {instance_number}")
            
print_instance_numbers(destination_folder)
# Out:
# Nome do arquivo: 2z7dQVRT.dcm, InstanceNumber: 198
# Nome do arquivo: 1QB0GMyr.dcm, InstanceNumber: 10
# Nome do arquivo: eoXmsCs2.dcm, InstanceNumber: 181
# Nome do arquivo: hkUE01LN.dcm, InstanceNumber: 36
# Nome do arquivo: S5gauGZH.dcm, InstanceNumber: 111
# Nome do arquivo: QmtwQKc6.dcm, InstanceNumber: 129
# Nome do arquivo: BGRfmqx9.dcm, InstanceNumber: 142
# Nome do arquivo: 3yVL737M.dcm, InstanceNumber: 232
# Nome do arquivo: AGu1Thpc.dcm, InstanceNumber: 164
# Nome do arquivo: 47UpPt1I.dcm, InstanceNumber: 248
# Nome do arquivo: KuVTDnnv.dcm, InstanceNumber: 191
# Nome do arquivo: rPR5VII0.dcm, InstanceNumber: 56
# Nome do arquivo: leGL6aAh.dcm, InstanceNumber: 235
# Nome do arquivo: rnmlCiyy.dcm, InstanceNumber: 246
# Nome do arquivo: 4dv9LSob.dcm, InstanceNumber: 134
# Nome do arquivo: uRgk6ziX.dcm, InstanceNumber: 14
# Nome do arquivo: RnaX2FJA.dcm, InstanceNumber: 29
# Nome do arquivo: PBmbSLi3.dcm, InstanceNumber: 236
# Nome do arquivo: ccz8x0Fo.dcm, InstanceNumber: 6
# Nome do arquivo: wDBzm8wY.dcm, InstanceNumber: 183
# Nome do arquivo: vs4oF4JX.dcm, InstanceNumber: 231
# Nome do arquivo: PgnE1rcu.dcm, InstanceNumber: 208
# Nome do arquivo: gAXzDiCM.dcm, InstanceNumber: 119
# Nome do arquivo: hrbkL7yf.dcm, InstanceNumber: 95
# Nome do arquivo: jXOK3sQ9.dcm, InstanceNumber: 113
# Nome do arquivo: KxPhi5PU.dcm, InstanceNumber: 78
# Nome do arquivo: SB3gcxAG.dcm, InstanceNumber: 206
# Nome do arquivo: s9Xawd4A.dcm, InstanceNumber: 159
# Nome do arquivo: VquC2Lqu.dcm, InstanceNumber: 31
# Nome do arquivo: MzjpIlHc.dcm, InstanceNumber: 17
# Nome do arquivo: clE2ZRlt.dcm, InstanceNumber: 234
# Nome do arquivo: zC4qgS1q.dcm, InstanceNumber: 102
# Nome do arquivo: dL7Z3p5X.dcm, InstanceNumber: 92
# Nome do arquivo: fEBYw7Sn.dcm, InstanceNumber: 150
# Nome do arquivo: XGRofrwi.dcm, InstanceNumber: 226
# Nome do arquivo: 5UfsB8xL.dcm, InstanceNumber: 54
# Nome do arquivo: 8erwnRp8.dcm, InstanceNumber: 253
# Nome do arquivo: TtpXQVoJ.dcm, InstanceNumber: 173
# Nome do arquivo: rNMNwSbZ.dcm, InstanceNumber: 84
# Nome do arquivo: HTY8dlsk.dcm, InstanceNumber: 9
# Nome do arquivo: Tk1FQvBm.dcm, InstanceNumber: 93
# Nome do arquivo: JqnNf4kM.dcm, InstanceNumber: 38
# Nome do arquivo: iNVfibob.dcm, InstanceNumber: 30
# Nome do arquivo: RGLceAMT.dcm, InstanceNumber: 43
# Nome do arquivo: k6qfiu3i.dcm, InstanceNumber: 141
# Nome do arquivo: reSvdhCQ.dcm, InstanceNumber: 156
# Nome do arquivo: OyXCNvYm.dcm, InstanceNumber: 143
# Nome do arquivo: ed4kZWRW.dcm, InstanceNumber: 221
# Nome do arquivo: RL8fVW7E.dcm, InstanceNumber: 39
# Nome do arquivo: tOs0xACY.dcm, InstanceNumber: 185
# Nome do arquivo: kyxwItDN.dcm, InstanceNumber: 196
# Nome do arquivo: axdb1tNS.dcm, InstanceNumber: 139
# Nome do arquivo: tTOvmPZb.dcm, InstanceNumber: 49
# Nome do arquivo: UEZKw5J8.dcm, InstanceNumber: 35
# Nome do arquivo: eHIoG98A.dcm, InstanceNumber: 33
# Nome do arquivo: 4WQn0djn.dcm, InstanceNumber: 151
# Nome do arquivo: yY92k4q4.dcm, InstanceNumber: 212
# Nome do arquivo: CAYyAyKb.dcm, InstanceNumber: 122
# Nome do arquivo: ild9ZrBe.dcm, InstanceNumber: 174
# Nome do arquivo: lBNiQ6jd.dcm, InstanceNumber: 199
# Nome do arquivo: vZhdqg3D.dcm, InstanceNumber: 215
# Nome do arquivo: 4klfHtO5.dcm, InstanceNumber: 152
# Nome do arquivo: EjxYoAcl.dcm, InstanceNumber: 74
# Nome do arquivo: MdczNcqZ.dcm, InstanceNumber: 131
# Nome do arquivo: 7I3CdXUq.dcm, InstanceNumber: 203
# Nome do arquivo: W9thvAvc.dcm, InstanceNumber: 177
# Nome do arquivo: RetohqvV.dcm, InstanceNumber: 216
# Nome do arquivo: bhmctNBH.dcm, InstanceNumber: 60
# Nome do arquivo: qmuqRTtB.dcm, InstanceNumber: 61
# Nome do arquivo: Xs45UBEn.dcm, InstanceNumber: 52
# Nome do arquivo: KSevuvj2.dcm, InstanceNumber: 90
# Nome do arquivo: 5HTlIJ4f.dcm, InstanceNumber: 200
# Nome do arquivo: pXj9aTb2.dcm, InstanceNumber: 120
# Nome do arquivo: 9A6fOffP.dcm, InstanceNumber: 210
# Nome do arquivo: 9OCaJj2r.dcm, InstanceNumber: 257
# Nome do arquivo: Q1zQ2ahd.dcm, InstanceNumber: 20
# Nome do arquivo: fMaAccN8.dcm, InstanceNumber: 12
# Nome do arquivo: 8rDYIFk2.dcm, InstanceNumber: 252
# Nome do arquivo: fY9iZ1vl.dcm, InstanceNumber: 103
# Nome do arquivo: Uc5HKWlG.dcm, InstanceNumber: 158
# Nome do arquivo: lptCIPqs.dcm, InstanceNumber: 109
# Nome do arquivo: 5nVBKmEx.dcm, InstanceNumber: 76
# Nome do arquivo: sLLjEcZD.dcm, InstanceNumber: 32
# Nome do arquivo: f1eiHHTp.dcm, InstanceNumber: 125
# Nome do arquivo: DK6HLpmf.dcm, InstanceNumber: 179
# Nome do arquivo: VLWhnzy4.dcm, InstanceNumber: 218
# Nome do arquivo: H9psQbQM.dcm, InstanceNumber: 83
# Nome do arquivo: Q0gao5FD.dcm, InstanceNumber: 260
# Nome do arquivo: P1ohsRPA.dcm, InstanceNumber: 178
# Nome do arquivo: 1Ja84lS5.dcm, InstanceNumber: 75
# Nome do arquivo: 84AlSKxc.dcm, InstanceNumber: 100
# Nome do arquivo: JMhp85O8.dcm, InstanceNumber: 69
# Nome do arquivo: ToeI0QIx.dcm, InstanceNumber: 249
# Nome do arquivo: c9VIPdIl.dcm, InstanceNumber: 26
# Nome do arquivo: vkAdV1sf.dcm, InstanceNumber: 123
# Nome do arquivo: 5RsMMTDz.dcm, InstanceNumber: 50
# Nome do arquivo: hXJWPRsP.dcm, InstanceNumber: 2
# Nome do arquivo: xyufAll2.dcm, InstanceNumber: 55
# Nome do arquivo: Wy3TC5Ur.dcm, InstanceNumber: 241
# Nome do arquivo: 63tqK8Nf.dcm, InstanceNumber: 3
# Nome do arquivo: pGrpyhnH.dcm, InstanceNumber: 171
# Nome do arquivo: aK2met9u.dcm, InstanceNumber: 114
# Nome do arquivo: x5uC8ciJ.dcm, InstanceNumber: 217
# Nome do arquivo: ZTEZPquT.dcm, InstanceNumber: 229
# Nome do arquivo: lsW5Tcu4.dcm, InstanceNumber: 219
# Nome do arquivo: Uld03S11.dcm, InstanceNumber: 42
# Nome do arquivo: 4SNhD9gR.dcm, InstanceNumber: 96
# Nome do arquivo: cXKHibdd.dcm, InstanceNumber: 107
# Nome do arquivo: vXfTzrZ1.dcm, InstanceNumber: 5
# Nome do arquivo: R8xLH11j.dcm, InstanceNumber: 182
# Nome do arquivo: btOT4TIy.dcm, InstanceNumber: 72
# Nome do arquivo: al6kiCEm.dcm, InstanceNumber: 190
# Nome do arquivo: lsk2zSOB.dcm, InstanceNumber: 58
# Nome do arquivo: G9fS5Jb4.dcm, InstanceNumber: 170
# Nome do arquivo: ui8EqSOU.dcm, InstanceNumber: 46
# Nome do arquivo: zPEAe85P.dcm, InstanceNumber: 126
# Nome do arquivo: cm6GRHGO.dcm, InstanceNumber: 80
# Nome do arquivo: isuRc0HB.dcm, InstanceNumber: 132
# Nome do arquivo: 7qM4ycvK.dcm, InstanceNumber: 144
# Nome do arquivo: 3mqEj1C9.dcm, InstanceNumber: 137
# Nome do arquivo: mw3iwsjQ.dcm, InstanceNumber: 68
# Nome do arquivo: 8YDnAW9l.dcm, InstanceNumber: 145
# Nome do arquivo: 6Sjc2Sjx.dcm, InstanceNumber: 166
# Nome do arquivo: cEyhZakp.dcm, InstanceNumber: 71
# Nome do arquivo: StLjP4Hn.dcm, InstanceNumber: 251
# Nome do arquivo: EOjcG3Ce.dcm, InstanceNumber: 115
# Nome do arquivo: b2w9HiDB.dcm, InstanceNumber: 11
# Nome do arquivo: FJ26MrMe.dcm, InstanceNumber: 85
# Nome do arquivo: cCfQa4wB.dcm, InstanceNumber: 23
# Nome do arquivo: SrFEMttv.dcm, InstanceNumber: 65
# Nome do arquivo: ijAsV5sX.dcm, InstanceNumber: 188
# Nome do arquivo: CRN8ombN.dcm, InstanceNumber: 187
# Nome do arquivo: be4couxI.dcm, InstanceNumber: 258
# Nome do arquivo: uPGGVd06.dcm, InstanceNumber: 193
# Nome do arquivo: bw570cvN.dcm, InstanceNumber: 189
# Nome do arquivo: A70Sf9xe.dcm, InstanceNumber: 180
# Nome do arquivo: cnPfhMF8.dcm, InstanceNumber: 195
# Nome do arquivo: ZHv7eXfL.dcm, InstanceNumber: 112
# Nome do arquivo: zhSnUPSF.dcm, InstanceNumber: 62
# Nome do arquivo: Rm0JTiLY.dcm, InstanceNumber: 98
# Nome do arquivo: 9r6z9pUN.dcm, InstanceNumber: 86
# Nome do arquivo: jytrFCwO.dcm, InstanceNumber: 227
# Nome do arquivo: pIYhYNGW.dcm, InstanceNumber: 25
# Nome do arquivo: D7JnD3Ny.dcm, InstanceNumber: 57
# Nome do arquivo: M6P9bQM1.dcm, InstanceNumber: 40
# Nome do arquivo: ikufQWZw.dcm, InstanceNumber: 79
# Nome do arquivo: gyUKHI3F.dcm, InstanceNumber: 47
# Nome do arquivo: oJCjyxfR.dcm, InstanceNumber: 192
# Nome do arquivo: lD3LhcyN.dcm, InstanceNumber: 220
# Nome do arquivo: An9eT47I.dcm, InstanceNumber: 21
# Nome do arquivo: alfrZHT0.dcm, InstanceNumber: 70
# Nome do arquivo: 8qLG77vr.dcm, InstanceNumber: 255
# Nome do arquivo: 3uA8t5Q2.dcm, InstanceNumber: 207
# Nome do arquivo: w4fYkE5w.dcm, InstanceNumber: 224
# Nome do arquivo: pKp6rxbZ.dcm, InstanceNumber: 202
# Nome do arquivo: Hc2Y0yur.dcm, InstanceNumber: 16
# Nome do arquivo: hqpSUxza.dcm, InstanceNumber: 124
# Nome do arquivo: TDeBpG2o.dcm, InstanceNumber: 94
# Nome do arquivo: H9FcKFrY.dcm, InstanceNumber: 128
# Nome do arquivo: Tc2KUnpq.dcm, InstanceNumber: 106
# Nome do arquivo: cVQ84po3.dcm, InstanceNumber: 7
# Nome do arquivo: ETbSWxrT.dcm, InstanceNumber: 105
# Nome do arquivo: CDuR2x5C.dcm, InstanceNumber: 157
# Nome do arquivo: qYgLBGZ1.dcm, InstanceNumber: 136
# Nome do arquivo: U2FF8Ld7.dcm, InstanceNumber: 186
# Nome do arquivo: t7m5vdeo.dcm, InstanceNumber: 256
# Nome do arquivo: MB73UTgN.dcm, InstanceNumber: 101
# Nome do arquivo: ERGOWpcS.dcm, InstanceNumber: 13
# Nome do arquivo: yVbOMFyF.dcm, InstanceNumber: 28
# Nome do arquivo: 0YJCINnN.dcm, InstanceNumber: 51
# Nome do arquivo: I293JIui.dcm, InstanceNumber: 44
# Nome do arquivo: n4jMsC4j.dcm, InstanceNumber: 261
# Nome do arquivo: 8oDXxo3l.dcm, InstanceNumber: 138
# Nome do arquivo: qEmXsNMj.dcm, InstanceNumber: 91
# Nome do arquivo: VLuwrLDu.dcm, InstanceNumber: 169
# Nome do arquivo: ysk3ud4n.dcm, InstanceNumber: 87
# Nome do arquivo: k1kLjuSG.dcm, InstanceNumber: 175
# Nome do arquivo: sScuL766.dcm, InstanceNumber: 242
# Nome do arquivo: Ch6CELf1.dcm, InstanceNumber: 127
# Nome do arquivo: 4tn8W2dg.dcm, InstanceNumber: 147
# Nome do arquivo: 720yaTEg.dcm, InstanceNumber: 45
# Nome do arquivo: kVzp7VKH.dcm, InstanceNumber: 230
# Nome do arquivo: Cv7pfjVX.dcm, InstanceNumber: 214
# Nome do arquivo: LGUkSaKO.dcm, InstanceNumber: 104
# Nome do arquivo: XMuhU1xJ.dcm, InstanceNumber: 82
# Nome do arquivo: LD7mSqtQ.dcm, InstanceNumber: 81
# Nome do arquivo: rE8jyaYr.dcm, InstanceNumber: 154
# Nome do arquivo: nK4ZQVPt.dcm, InstanceNumber: 117
# Nome do arquivo: PBsNmdyB.dcm, InstanceNumber: 250
# Nome do arquivo: 9uHwZTmr.dcm, InstanceNumber: 213
# Nome do arquivo: BNBJkX2H.dcm, InstanceNumber: 149
# Nome do arquivo: xVG8vjZA.dcm, InstanceNumber: 64
# Nome do arquivo: LUGZvZzB.dcm, InstanceNumber: 15
# Nome do arquivo: o09dh1vO.dcm, InstanceNumber: 168
# Nome do arquivo: xHlsmSAT.dcm, InstanceNumber: 228
# Nome do arquivo: mIYsYPh9.dcm, InstanceNumber: 24
# Nome do arquivo: BbRJhMmI.dcm, InstanceNumber: 77
# Nome do arquivo: aFjccky8.dcm, InstanceNumber: 130
# Nome do arquivo: WEbz5Wnc.dcm, InstanceNumber: 118
# Nome do arquivo: g6OeoIjQ.dcm, InstanceNumber: 247
# Nome do arquivo: fOEvK5Wz.dcm, InstanceNumber: 225
# Nome do arquivo: kxmuESYX.dcm, InstanceNumber: 48
# Nome do arquivo: j62tizjJ.dcm, InstanceNumber: 121
# Nome do arquivo: fYY0dcsJ.dcm, InstanceNumber: 194
# Nome do arquivo: JrjuUOAe.dcm, InstanceNumber: 197
# Nome do arquivo: u2otVEBY.dcm, InstanceNumber: 110
# Nome do arquivo: 57j31Xsi.dcm, InstanceNumber: 133
# Nome do arquivo: QLfiPmkr.dcm, InstanceNumber: 205
# Nome do arquivo: WXGuUUti.dcm, InstanceNumber: 167
# Nome do arquivo: LQxTNwQm.dcm, InstanceNumber: 222
# Nome do arquivo: bvyzN4lB.dcm, InstanceNumber: 233
# Nome do arquivo: h7ZM9ysw.dcm, InstanceNumber: 209
# Nome do arquivo: GyThBRJc.dcm, InstanceNumber: 245
# Nome do arquivo: Cepl2C60.dcm, InstanceNumber: 211
# Nome do arquivo: VIy9GrKK.dcm, InstanceNumber: 1
# Nome do arquivo: vpmcjui0.dcm, InstanceNumber: 238
# Nome do arquivo: wCu8nxbj.dcm, InstanceNumber: 172
# Nome do arquivo: Jd5vRkOS.dcm, InstanceNumber: 146
# Nome do arquivo: ktlyGaEj.dcm, InstanceNumber: 89
# Nome do arquivo: LrqeEYxu.dcm, InstanceNumber: 165
# Nome do arquivo: tfSq1PYF.dcm, InstanceNumber: 88
# Nome do arquivo: 7hpBZj9X.dcm, InstanceNumber: 53
# Nome do arquivo: be8mKOP0.dcm, InstanceNumber: 116
# Nome do arquivo: D2onHaKU.dcm, InstanceNumber: 63
# Nome do arquivo: LmSljXfL.dcm, InstanceNumber: 160
# Nome do arquivo: UQ8P12Ry.dcm, InstanceNumber: 4
# Nome do arquivo: F3m6tJuI.dcm, InstanceNumber: 239
# Nome do arquivo: 6eRFYbd4.dcm, InstanceNumber: 240
# Nome do arquivo: WgF2Gy8E.dcm, InstanceNumber: 99
# Nome do arquivo: GDDq88tk.dcm, InstanceNumber: 237
# Nome do arquivo: rDpXPNfk.dcm, InstanceNumber: 244
# Nome do arquivo: mvDDfJkL.dcm, InstanceNumber: 27
# Nome do arquivo: 2Yr5ZxwS.dcm, InstanceNumber: 153
# Nome do arquivo: CJxrTPwn.dcm, InstanceNumber: 162
# Nome do arquivo: suH2S6jn.dcm, InstanceNumber: 67
# Nome do arquivo: j6wtXLc3.dcm, InstanceNumber: 155
# Nome do arquivo: z67ALgOP.dcm, InstanceNumber: 34
# Nome do arquivo: ic5QE9rL.dcm, InstanceNumber: 259
# Nome do arquivo: DWwJ8j8n.dcm, InstanceNumber: 22
# Nome do arquivo: tFYqabOR.dcm, InstanceNumber: 41
# Nome do arquivo: Ac655DQr.dcm, InstanceNumber: 18
# Nome do arquivo: k4y0K426.dcm, InstanceNumber: 201
# Nome do arquivo: ktpTG459.dcm, InstanceNumber: 184
# Nome do arquivo: I6p5OVLn.dcm, InstanceNumber: 161
# Nome do arquivo: euquyTyV.dcm, InstanceNumber: 223
# Nome do arquivo: gX0syAah.dcm, InstanceNumber: 148
# Nome do arquivo: XURErAJl.dcm, InstanceNumber: 135
# Nome do arquivo: PPIzHhlh.dcm, InstanceNumber: 73
# Nome do arquivo: rCndt4ZX.dcm, InstanceNumber: 108
# Nome do arquivo: 1Lemu4QW.dcm, InstanceNumber: 8
# Nome do arquivo: 3F0ylIBM.dcm, InstanceNumber: 97
# Nome do arquivo: 5bEVO5wF.dcm, InstanceNumber: 37
# Nome do arquivo: 9uWk3D8o.dcm, InstanceNumber: 66
# Nome do arquivo: K1ae5EtH.dcm, InstanceNumber: 163
# Nome do arquivo: H69PQpzj.dcm, InstanceNumber: 176
# Nome do arquivo: p3ZTB4oN.dcm, InstanceNumber: 59
# Nome do arquivo: jcjuU3yX.dcm, InstanceNumber: 140
# Nome do arquivo: BDHA6dgs.dcm, InstanceNumber: 243
# Nome do arquivo: ZctwcL4Z.dcm, InstanceNumber: 204
# Nome do arquivo: SLZ2PWi7.dcm, InstanceNumber: 254
# Nome do arquivo: 83WwB9fc.dcm, InstanceNumber: 19

# %% [markdown]
# Como podemos visualizar, eles foram armazenados fora de ordem, e isso faz com que a visualização final esteja incorreta, mostrando cortes desordenados.
# Ordenando...

# %%
def sort_dicom_files_by_instance_number(folder_path):
    dicom_files = [os.path.join(folder_path, arquivo) for arquivo in os.listdir(folder_path) if arquivo.endswith('.dcm')]
    
    def get_instance_number(file_path):
        dicom_data = pydicom.dcmread(file_path)
        return dicom_data.InstanceNumber

    dicom_files = sorted(dicom_files, key=get_instance_number)
    
    return dicom_files

if __name__ == "__main__":
    dicom_files = sort_dicom_files_by_instance_number(destination_folder)

    for arquivo in dicom_files:
        dicom_data = pydicom.dcmread(arquivo)
        instance_number = dicom_data.InstanceNumber
        print(f"Nome do arquivo: {os.path.basename(arquivo)}, InstanceNumber = {instance_number}")
# Out:
# Nome do arquivo: VIy9GrKK.dcm, InstanceNumber = 1
# Nome do arquivo: hXJWPRsP.dcm, InstanceNumber = 2
# Nome do arquivo: 63tqK8Nf.dcm, InstanceNumber = 3
# Nome do arquivo: UQ8P12Ry.dcm, InstanceNumber = 4
# Nome do arquivo: vXfTzrZ1.dcm, InstanceNumber = 5
# Nome do arquivo: ccz8x0Fo.dcm, InstanceNumber = 6
# Nome do arquivo: cVQ84po3.dcm, InstanceNumber = 7
# Nome do arquivo: 1Lemu4QW.dcm, InstanceNumber = 8
# Nome do arquivo: HTY8dlsk.dcm, InstanceNumber = 9
# Nome do arquivo: 1QB0GMyr.dcm, InstanceNumber = 10
# Nome do arquivo: b2w9HiDB.dcm, InstanceNumber = 11
# Nome do arquivo: fMaAccN8.dcm, InstanceNumber = 12
# Nome do arquivo: ERGOWpcS.dcm, InstanceNumber = 13
# Nome do arquivo: uRgk6ziX.dcm, InstanceNumber = 14
# Nome do arquivo: LUGZvZzB.dcm, InstanceNumber = 15
# Nome do arquivo: Hc2Y0yur.dcm, InstanceNumber = 16
# Nome do arquivo: MzjpIlHc.dcm, InstanceNumber = 17
# Nome do arquivo: Ac655DQr.dcm, InstanceNumber = 18
# Nome do arquivo: 83WwB9fc.dcm, InstanceNumber = 19
# Nome do arquivo: Q1zQ2ahd.dcm, InstanceNumber = 20
# Nome do arquivo: An9eT47I.dcm, InstanceNumber = 21
# Nome do arquivo: DWwJ8j8n.dcm, InstanceNumber = 22
# Nome do arquivo: cCfQa4wB.dcm, InstanceNumber = 23
# Nome do arquivo: mIYsYPh9.dcm, InstanceNumber = 24
# Nome do arquivo: pIYhYNGW.dcm, InstanceNumber = 25
# Nome do arquivo: c9VIPdIl.dcm, InstanceNumber = 26
# Nome do arquivo: mvDDfJkL.dcm, InstanceNumber = 27
# Nome do arquivo: yVbOMFyF.dcm, InstanceNumber = 28
# Nome do arquivo: RnaX2FJA.dcm, InstanceNumber = 29
# Nome do arquivo: iNVfibob.dcm, InstanceNumber = 30
# Nome do arquivo: VquC2Lqu.dcm, InstanceNumber = 31
# Nome do arquivo: sLLjEcZD.dcm, InstanceNumber = 32
# Nome do arquivo: eHIoG98A.dcm, InstanceNumber = 33
# Nome do arquivo: z67ALgOP.dcm, InstanceNumber = 34
# Nome do arquivo: UEZKw5J8.dcm, InstanceNumber = 35
# Nome do arquivo: hkUE01LN.dcm, InstanceNumber = 36
# Nome do arquivo: 5bEVO5wF.dcm, InstanceNumber = 37
# Nome do arquivo: JqnNf4kM.dcm, InstanceNumber = 38
# Nome do arquivo: RL8fVW7E.dcm, InstanceNumber = 39
# Nome do arquivo: M6P9bQM1.dcm, InstanceNumber = 40
# Nome do arquivo: tFYqabOR.dcm, InstanceNumber = 41
# Nome do arquivo: Uld03S11.dcm, InstanceNumber = 42
# Nome do arquivo: RGLceAMT.dcm, InstanceNumber = 43
# Nome do arquivo: I293JIui.dcm, InstanceNumber = 44
# Nome do arquivo: 720yaTEg.dcm, InstanceNumber = 45
# Nome do arquivo: ui8EqSOU.dcm, InstanceNumber = 46
# Nome do arquivo: gyUKHI3F.dcm, InstanceNumber = 47
# Nome do arquivo: kxmuESYX.dcm, InstanceNumber = 48
# Nome do arquivo: tTOvmPZb.dcm, InstanceNumber = 49
# Nome do arquivo: 5RsMMTDz.dcm, InstanceNumber = 50
# Nome do arquivo: 0YJCINnN.dcm, InstanceNumber = 51
# Nome do arquivo: Xs45UBEn.dcm, InstanceNumber = 52
# Nome do arquivo: 7hpBZj9X.dcm, InstanceNumber = 53
# Nome do arquivo: 5UfsB8xL.dcm, InstanceNumber = 54
# Nome do arquivo: xyufAll2.dcm, InstanceNumber = 55
# Nome do arquivo: rPR5VII0.dcm, InstanceNumber = 56
# Nome do arquivo: D7JnD3Ny.dcm, InstanceNumber = 57
# Nome do arquivo: lsk2zSOB.dcm, InstanceNumber = 58
# Nome do arquivo: p3ZTB4oN.dcm, InstanceNumber = 59
# Nome do arquivo: bhmctNBH.dcm, InstanceNumber = 60
# Nome do arquivo: qmuqRTtB.dcm, InstanceNumber = 61
# Nome do arquivo: zhSnUPSF.dcm, InstanceNumber = 62
# Nome do arquivo: D2onHaKU.dcm, InstanceNumber = 63
# Nome do arquivo: xVG8vjZA.dcm, InstanceNumber = 64
# Nome do arquivo: SrFEMttv.dcm, InstanceNumber = 65
# Nome do arquivo: 9uWk3D8o.dcm, InstanceNumber = 66
# Nome do arquivo: suH2S6jn.dcm, InstanceNumber = 67
# Nome do arquivo: mw3iwsjQ.dcm, InstanceNumber = 68
# Nome do arquivo: JMhp85O8.dcm, InstanceNumber = 69
# Nome do arquivo: alfrZHT0.dcm, InstanceNumber = 70
# Nome do arquivo: cEyhZakp.dcm, InstanceNumber = 71
# Nome do arquivo: btOT4TIy.dcm, InstanceNumber = 72
# Nome do arquivo: PPIzHhlh.dcm, InstanceNumber = 73
# Nome do arquivo: EjxYoAcl.dcm, InstanceNumber = 74
# Nome do arquivo: 1Ja84lS5.dcm, InstanceNumber = 75
# Nome do arquivo: 5nVBKmEx.dcm, InstanceNumber = 76
# Nome do arquivo: BbRJhMmI.dcm, InstanceNumber = 77
# Nome do arquivo: KxPhi5PU.dcm, InstanceNumber = 78
# Nome do arquivo: ikufQWZw.dcm, InstanceNumber = 79
# Nome do arquivo: cm6GRHGO.dcm, InstanceNumber = 80
# Nome do arquivo: LD7mSqtQ.dcm, InstanceNumber = 81
# Nome do arquivo: XMuhU1xJ.dcm, InstanceNumber = 82
# Nome do arquivo: H9psQbQM.dcm, InstanceNumber = 83
# Nome do arquivo: rNMNwSbZ.dcm, InstanceNumber = 84
# Nome do arquivo: FJ26MrMe.dcm, InstanceNumber = 85
# Nome do arquivo: 9r6z9pUN.dcm, InstanceNumber = 86
# Nome do arquivo: ysk3ud4n.dcm, InstanceNumber = 87
# Nome do arquivo: tfSq1PYF.dcm, InstanceNumber = 88
# Nome do arquivo: ktlyGaEj.dcm, InstanceNumber = 89
# Nome do arquivo: KSevuvj2.dcm, InstanceNumber = 90
# Nome do arquivo: qEmXsNMj.dcm, InstanceNumber = 91
# Nome do arquivo: dL7Z3p5X.dcm, InstanceNumber = 92
# Nome do arquivo: Tk1FQvBm.dcm, InstanceNumber = 93
# Nome do arquivo: TDeBpG2o.dcm, InstanceNumber = 94
# Nome do arquivo: hrbkL7yf.dcm, InstanceNumber = 95
# Nome do arquivo: 4SNhD9gR.dcm, InstanceNumber = 96
# Nome do arquivo: 3F0ylIBM.dcm, InstanceNumber = 97
# Nome do arquivo: Rm0JTiLY.dcm, InstanceNumber = 98
# Nome do arquivo: WgF2Gy8E.dcm, InstanceNumber = 99
# Nome do arquivo: 84AlSKxc.dcm, InstanceNumber = 100
# Nome do arquivo: MB73UTgN.dcm, InstanceNumber = 101
# Nome do arquivo: zC4qgS1q.dcm, InstanceNumber = 102
# Nome do arquivo: fY9iZ1vl.dcm, InstanceNumber = 103
# Nome do arquivo: LGUkSaKO.dcm, InstanceNumber = 104
# Nome do arquivo: ETbSWxrT.dcm, InstanceNumber = 105
# Nome do arquivo: Tc2KUnpq.dcm, InstanceNumber = 106
# Nome do arquivo: cXKHibdd.dcm, InstanceNumber = 107
# Nome do arquivo: rCndt4ZX.dcm, InstanceNumber = 108
# Nome do arquivo: lptCIPqs.dcm, InstanceNumber = 109
# Nome do arquivo: u2otVEBY.dcm, InstanceNumber = 110
# Nome do arquivo: S5gauGZH.dcm, InstanceNumber = 111
# Nome do arquivo: ZHv7eXfL.dcm, InstanceNumber = 112
# Nome do arquivo: jXOK3sQ9.dcm, InstanceNumber = 113
# Nome do arquivo: aK2met9u.dcm, InstanceNumber = 114
# Nome do arquivo: EOjcG3Ce.dcm, InstanceNumber = 115
# Nome do arquivo: be8mKOP0.dcm, InstanceNumber = 116
# Nome do arquivo: nK4ZQVPt.dcm, InstanceNumber = 117
# Nome do arquivo: WEbz5Wnc.dcm, InstanceNumber = 118
# Nome do arquivo: gAXzDiCM.dcm, InstanceNumber = 119
# Nome do arquivo: pXj9aTb2.dcm, InstanceNumber = 120
# Nome do arquivo: j62tizjJ.dcm, InstanceNumber = 121
# Nome do arquivo: CAYyAyKb.dcm, InstanceNumber = 122
# Nome do arquivo: vkAdV1sf.dcm, InstanceNumber = 123
# Nome do arquivo: hqpSUxza.dcm, InstanceNumber = 124
# Nome do arquivo: f1eiHHTp.dcm, InstanceNumber = 125
# Nome do arquivo: zPEAe85P.dcm, InstanceNumber = 126
# Nome do arquivo: Ch6CELf1.dcm, InstanceNumber = 127
# Nome do arquivo: H9FcKFrY.dcm, InstanceNumber = 128
# Nome do arquivo: QmtwQKc6.dcm, InstanceNumber = 129
# Nome do arquivo: aFjccky8.dcm, InstanceNumber = 130
# Nome do arquivo: MdczNcqZ.dcm, InstanceNumber = 131
# Nome do arquivo: isuRc0HB.dcm, InstanceNumber = 132
# Nome do arquivo: 57j31Xsi.dcm, InstanceNumber = 133
# Nome do arquivo: 4dv9LSob.dcm, InstanceNumber = 134
# Nome do arquivo: XURErAJl.dcm, InstanceNumber = 135
# Nome do arquivo: qYgLBGZ1.dcm, InstanceNumber = 136
# Nome do arquivo: 3mqEj1C9.dcm, InstanceNumber = 137
# Nome do arquivo: 8oDXxo3l.dcm, InstanceNumber = 138
# Nome do arquivo: axdb1tNS.dcm, InstanceNumber = 139
# Nome do arquivo: jcjuU3yX.dcm, InstanceNumber = 140
# Nome do arquivo: k6qfiu3i.dcm, InstanceNumber = 141
# Nome do arquivo: BGRfmqx9.dcm, InstanceNumber = 142
# Nome do arquivo: OyXCNvYm.dcm, InstanceNumber = 143
# Nome do arquivo: 7qM4ycvK.dcm, InstanceNumber = 144
# Nome do arquivo: 8YDnAW9l.dcm, InstanceNumber = 145
# Nome do arquivo: Jd5vRkOS.dcm, InstanceNumber = 146
# Nome do arquivo: 4tn8W2dg.dcm, InstanceNumber = 147
# Nome do arquivo: gX0syAah.dcm, InstanceNumber = 148
# Nome do arquivo: BNBJkX2H.dcm, InstanceNumber = 149
# Nome do arquivo: fEBYw7Sn.dcm, InstanceNumber = 150
# Nome do arquivo: 4WQn0djn.dcm, InstanceNumber = 151
# Nome do arquivo: 4klfHtO5.dcm, InstanceNumber = 152
# Nome do arquivo: 2Yr5ZxwS.dcm, InstanceNumber = 153
# Nome do arquivo: rE8jyaYr.dcm, InstanceNumber = 154
# Nome do arquivo: j6wtXLc3.dcm, InstanceNumber = 155
# Nome do arquivo: reSvdhCQ.dcm, InstanceNumber = 156
# Nome do arquivo: CDuR2x5C.dcm, InstanceNumber = 157
# Nome do arquivo: Uc5HKWlG.dcm, InstanceNumber = 158
# Nome do arquivo: s9Xawd4A.dcm, InstanceNumber = 159
# Nome do arquivo: LmSljXfL.dcm, InstanceNumber = 160
# Nome do arquivo: I6p5OVLn.dcm, InstanceNumber = 161
# Nome do arquivo: CJxrTPwn.dcm, InstanceNumber = 162
# Nome do arquivo: K1ae5EtH.dcm, InstanceNumber = 163
# Nome do arquivo: AGu1Thpc.dcm, InstanceNumber = 164
# Nome do arquivo: LrqeEYxu.dcm, InstanceNumber = 165
# Nome do arquivo: 6Sjc2Sjx.dcm, InstanceNumber = 166
# Nome do arquivo: WXGuUUti.dcm, InstanceNumber = 167
# Nome do arquivo: o09dh1vO.dcm, InstanceNumber = 168
# Nome do arquivo: VLuwrLDu.dcm, InstanceNumber = 169
# Nome do arquivo: G9fS5Jb4.dcm, InstanceNumber = 170
# Nome do arquivo: pGrpyhnH.dcm, InstanceNumber = 171
# Nome do arquivo: wCu8nxbj.dcm, InstanceNumber = 172
# Nome do arquivo: TtpXQVoJ.dcm, InstanceNumber = 173
# Nome do arquivo: ild9ZrBe.dcm, InstanceNumber = 174
# Nome do arquivo: k1kLjuSG.dcm, InstanceNumber = 175
# Nome do arquivo: H69PQpzj.dcm, InstanceNumber = 176
# Nome do arquivo: W9thvAvc.dcm, InstanceNumber = 177
# Nome do arquivo: P1ohsRPA.dcm, InstanceNumber = 178
# Nome do arquivo: DK6HLpmf.dcm, InstanceNumber = 179
# Nome do arquivo: A70Sf9xe.dcm, InstanceNumber = 180
# Nome do arquivo: eoXmsCs2.dcm, InstanceNumber = 181
# Nome do arquivo: R8xLH11j.dcm, InstanceNumber = 182
# Nome do arquivo: wDBzm8wY.dcm, InstanceNumber = 183
# Nome do arquivo: ktpTG459.dcm, InstanceNumber = 184
# Nome do arquivo: tOs0xACY.dcm, InstanceNumber = 185
# Nome do arquivo: U2FF8Ld7.dcm, InstanceNumber = 186
# Nome do arquivo: CRN8ombN.dcm, InstanceNumber = 187
# Nome do arquivo: ijAsV5sX.dcm, InstanceNumber = 188
# Nome do arquivo: bw570cvN.dcm, InstanceNumber = 189
# Nome do arquivo: al6kiCEm.dcm, InstanceNumber = 190
# Nome do arquivo: KuVTDnnv.dcm, InstanceNumber = 191
# Nome do arquivo: oJCjyxfR.dcm, InstanceNumber = 192
# Nome do arquivo: uPGGVd06.dcm, InstanceNumber = 193
# Nome do arquivo: fYY0dcsJ.dcm, InstanceNumber = 194
# Nome do arquivo: cnPfhMF8.dcm, InstanceNumber = 195
# Nome do arquivo: kyxwItDN.dcm, InstanceNumber = 196
# Nome do arquivo: JrjuUOAe.dcm, InstanceNumber = 197
# Nome do arquivo: 2z7dQVRT.dcm, InstanceNumber = 198
# Nome do arquivo: lBNiQ6jd.dcm, InstanceNumber = 199
# Nome do arquivo: 5HTlIJ4f.dcm, InstanceNumber = 200
# Nome do arquivo: k4y0K426.dcm, InstanceNumber = 201
# Nome do arquivo: pKp6rxbZ.dcm, InstanceNumber = 202
# Nome do arquivo: 7I3CdXUq.dcm, InstanceNumber = 203
# Nome do arquivo: ZctwcL4Z.dcm, InstanceNumber = 204
# Nome do arquivo: QLfiPmkr.dcm, InstanceNumber = 205
# Nome do arquivo: SB3gcxAG.dcm, InstanceNumber = 206
# Nome do arquivo: 3uA8t5Q2.dcm, InstanceNumber = 207
# Nome do arquivo: PgnE1rcu.dcm, InstanceNumber = 208
# Nome do arquivo: h7ZM9ysw.dcm, InstanceNumber = 209
# Nome do arquivo: 9A6fOffP.dcm, InstanceNumber = 210
# Nome do arquivo: Cepl2C60.dcm, InstanceNumber = 211
# Nome do arquivo: yY92k4q4.dcm, InstanceNumber = 212
# Nome do arquivo: 9uHwZTmr.dcm, InstanceNumber = 213
# Nome do arquivo: Cv7pfjVX.dcm, InstanceNumber = 214
# Nome do arquivo: vZhdqg3D.dcm, InstanceNumber = 215
# Nome do arquivo: RetohqvV.dcm, InstanceNumber = 216
# Nome do arquivo: x5uC8ciJ.dcm, InstanceNumber = 217
# Nome do arquivo: VLWhnzy4.dcm, InstanceNumber = 218
# Nome do arquivo: lsW5Tcu4.dcm, InstanceNumber = 219
# Nome do arquivo: lD3LhcyN.dcm, InstanceNumber = 220
# Nome do arquivo: ed4kZWRW.dcm, InstanceNumber = 221
# Nome do arquivo: LQxTNwQm.dcm, InstanceNumber = 222
# Nome do arquivo: euquyTyV.dcm, InstanceNumber = 223
# Nome do arquivo: w4fYkE5w.dcm, InstanceNumber = 224
# Nome do arquivo: fOEvK5Wz.dcm, InstanceNumber = 225
# Nome do arquivo: XGRofrwi.dcm, InstanceNumber = 226
# Nome do arquivo: jytrFCwO.dcm, InstanceNumber = 227
# Nome do arquivo: xHlsmSAT.dcm, InstanceNumber = 228
# Nome do arquivo: ZTEZPquT.dcm, InstanceNumber = 229
# Nome do arquivo: kVzp7VKH.dcm, InstanceNumber = 230
# Nome do arquivo: vs4oF4JX.dcm, InstanceNumber = 231
# Nome do arquivo: 3yVL737M.dcm, InstanceNumber = 232
# Nome do arquivo: bvyzN4lB.dcm, InstanceNumber = 233
# Nome do arquivo: clE2ZRlt.dcm, InstanceNumber = 234
# Nome do arquivo: leGL6aAh.dcm, InstanceNumber = 235
# Nome do arquivo: PBmbSLi3.dcm, InstanceNumber = 236
# Nome do arquivo: GDDq88tk.dcm, InstanceNumber = 237
# Nome do arquivo: vpmcjui0.dcm, InstanceNumber = 238
# Nome do arquivo: F3m6tJuI.dcm, InstanceNumber = 239
# Nome do arquivo: 6eRFYbd4.dcm, InstanceNumber = 240
# Nome do arquivo: Wy3TC5Ur.dcm, InstanceNumber = 241
# Nome do arquivo: sScuL766.dcm, InstanceNumber = 242
# Nome do arquivo: BDHA6dgs.dcm, InstanceNumber = 243
# Nome do arquivo: rDpXPNfk.dcm, InstanceNumber = 244
# Nome do arquivo: GyThBRJc.dcm, InstanceNumber = 245
# Nome do arquivo: rnmlCiyy.dcm, InstanceNumber = 246
# Nome do arquivo: g6OeoIjQ.dcm, InstanceNumber = 247
# Nome do arquivo: 47UpPt1I.dcm, InstanceNumber = 248
# Nome do arquivo: ToeI0QIx.dcm, InstanceNumber = 249
# Nome do arquivo: PBsNmdyB.dcm, InstanceNumber = 250
# Nome do arquivo: StLjP4Hn.dcm, InstanceNumber = 251
# Nome do arquivo: 8rDYIFk2.dcm, InstanceNumber = 252
# Nome do arquivo: 8erwnRp8.dcm, InstanceNumber = 253
# Nome do arquivo: SLZ2PWi7.dcm, InstanceNumber = 254
# Nome do arquivo: 8qLG77vr.dcm, InstanceNumber = 255
# Nome do arquivo: t7m5vdeo.dcm, InstanceNumber = 256
# Nome do arquivo: 9OCaJj2r.dcm, InstanceNumber = 257
# Nome do arquivo: be4couxI.dcm, InstanceNumber = 258
# Nome do arquivo: ic5QE9rL.dcm, InstanceNumber = 259
# Nome do arquivo: Q0gao5FD.dcm, InstanceNumber = 260
# Nome do arquivo: n4jMsC4j.dcm, InstanceNumber = 261

# %%
interact(visualizar_tomografia, corte=(0, len(dicom_files)-1))
# Out:
# interactive(children=(IntSlider(value=130, description='corte', max=260), Output()), _dom_classes=('widget-int…
# <function __main__.visualizar_tomografia(corte)>
